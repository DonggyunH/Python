# %%
import os 
os.getcwd()
# Out:
# 'c:\\Users\\acorn\\Desktop'

# %%
import pandas as pd 
test = pd.read_csv('./홍동균/test.csv')
# train = pd.read_csv('./홍동균/train.csv')
# train_ = pd.read_csv('./홍동균/train.csv')

# %%
import seaborn as sns

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
object_col = train.select_dtypes('object').columns

# %%
for i in object_col : 
    print(train[i].value_counts())
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# ...

# %%
train.SaleCondition.value_counts().head(1).index[0]
# Out:
# 'Normal'

# %%
missing_col = train.columns[train.isnull().sum() > 0]
print(f'missing_colunms : ',missing_col)
# Out:
# missing_colunms :  Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
train[missing_col].isnull().sum()
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
train.PoolQC.value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %%
for i in missing_col : 
    print(train[i].value_counts())
# Out:
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 182.0      1
# 160.0      1
# 152.0      1
# 153.0      1
# 46.0       1
# Name: count, Length: 110, dtype: int64
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64
# MasVnrArea
# 0.0      861
# 108.0      8
# 72.0       8
# 180.0      8
# 16.0       7
#         ...
# 426.0      1
# 96.0       1
# 438.0      1
# 194.0      1
# 119.0      1
# Name: count, Length: 327, dtype: int64
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: count, dtype: int64
# BsmtFinType2
# ...

# %%
object_missing = train[missing_col].select_dtypes(object).columns
number_missing = train[missing_col].select_dtypes([int,float]).columns

# %%
object_missing
# Out:
# Index(['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC',
#        'Fence', 'MiscFeature'],
#       dtype='object')

# %%
train[number_missing[0]]
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
# for i in object_missing : 
#     train[i] = train[i].fillna('Missing')
# for i in number_missing:
#     train[i] = train[i].fillna(train[i].mean())
for i in object_missing : 
    test[i] = test[i].fillna('Missing')
for i in number_missing:
    test[i] = test[i].fillna(test[i].mean())

# %%
train.columns[train.isnull().sum() > 0]
# Out:
# Index(['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC',
#        'Fence', 'MiscFeature'],
#       dtype='object')

# %%
a.index
# Out:
# Index([4, 5, 0, 3, 2, 1], dtype='int64', name='SaleCondition')

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# for i in object_col : 
#     train[i] = encoder.fit_transform(train[i])
#     a = train[i].value_counts()
#     print(f'{i} : {a.index}\n\t{a.values}')
for i in object_col : 
    test[i] = encoder.fit_transform(test[i])
    a = test[i].value_counts()
    print(f'{i} : {a.index}\n\t{a.values}')
# Out:
# MSZoning : Index([3, 4, 1, 0, 2, 5], dtype='int64', name='MSZoning')
# 	[1114  242   74   15   10    4]
# Street : Index([1, 0], dtype='int64', name='Street')
# 	[1453    6]
# Alley : Index([1, 0, 2], dtype='int64', name='Alley')
# 	[1352   70   37]
# LotShape : Index([3, 0, 1, 2], dtype='int64', name='LotShape')
# 	[934 484  35   6]
# LandContour : Index([3, 1, 0, 2], dtype='int64', name='LandContour')
# 	[1311   70   54   24]
# Utilities : Index([0, 1], dtype='int64', name='Utilities')
# 	[1457    2]
# LotConfig : Index([4, 0, 1, 2, 3], dtype='int64', name='LotConfig')
# 	[1081  248   82   38   10]
# LandSlope : Index([0, 1, 2], dtype='int64', name='LandSlope')
# 	[1396   60    3]
# Neighborhood : Index([12, 17,  5, 21,  7, 16,  8, 19, 20, 11, 14,  9,  6,  3, 23, 15, 22, 18,
#        10,  4,  2, 13, 24,  0,  1],
#       dtype='int64', name='Neighborhood')
# 	[218 126 117  96  94  89  86  77  66  65  58  56  52  50  34  30  26  23
#   20  16  14  14  13  11   8]
# ...

# %%
# train['YearBuilt'] = train.YearBuilt.astype(int)
test['YearBuilt'] = test.YearBuilt.astype(int)
# train['YearBuilt']

# %%
number_col = train.select_dtypes([int,float]).columns

# %%
X_train = train.drop('SalePrice', axis = 1, inplace = False)
y_train = train.SalePrice

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score

model = RandomForestRegressor(random_state=10)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=10)

# %%
importances = model.feature_importances_
selector = SelectFromModel(model, threshold='mean', prefit = True)
X_train_selected = selector.transform(X_train)
test_selected = selector.transform(test)
# Out:
# c:\Users\acorn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# c:\Users\acorn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
selected_features = X_train.columns[selector.get_support()]
print('Selected Features using RF : ',selected_features)
# Out:
# Selected Features using RF :  Index(['LotArea', 'OverallQual', 'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'GarageCars', 'GarageArea'],
#       dtype='object')

# %%
X_train = X_train.head(1459) 
y_train = y_train.head(1459)

# %%
y_pred
# Out:
# array([127920.32, 161581.51, 178129.5 , ..., 164785.55, 103600.5 ,
#        234785.39])

# %%
test.columns[test.isnull().sum() > 0]
# Out:
# Index(['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'GarageCars', 'GarageArea'],
#       dtype='object')

# %%
test[['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
       'BsmtHalfBath', 'GarageCars', 'GarageArea']].isnull().sum()
# Out:
# BsmtFinSF1      1
# BsmtFinSF2      1
# BsmtUnfSF       1
# TotalBsmtSF     1
# BsmtFullBath    2
# BsmtHalfBath    2
# GarageCars      1
# GarageArea      1
# dtype: int64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(test)

# 성능 평가
mse = mean_squared_error(test, y_pred)
mae = mean_absolute_error(test, y_pred)
r2 = r2_score(test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R² Score:", r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[273], line 8
#       5 y_pred = model.predict(test)
#       7 # 성능 평가
# ----> 8 mse = mean_squared_error(test, y_pred)
#       9 mae = mean_absolute_error(test, y_pred)
#      10 r2 = r2_score(test, y_pred)
#
# File c:\Users\acorn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
# ...
