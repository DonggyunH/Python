# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os 
os.getcwd()
# Out:
# 'c:\\Users\\acorn\\Desktop'

# %%
df = pd.read_csv('./acorn_file/Boston.csv')
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
df = df[['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','black','lstat','medv']]
df.rename(columns={df.columns[-1]:'price'},inplace=True)

# %%
col = ['price','rm','age','rad']

# %%
df_corr = df.corr()
df_corr
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# black   -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# price   -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               dis       rad       tax   ptratio     black     lstat     price
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# black    0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# price    0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
plt.figure(figsize = (10,10))
mask = np.array(df_corr)
mask[np.tril_indices_from(mask)] = False
sns.heatmap(df_corr, mask = mask, annot = True, cmap = 'magma')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.pairplot(df[col], kind = 'reg')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
y = df.price
x = df.drop(['price'], axis = 1, inplace=False)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=1)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (379, 13) (127, 13) (379,) (127,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-1.14428903e-01,  5.71299780e-02,  3.83002824e-02,  2.42854641e+00,
#        -2.12326236e+01,  2.87723416e+00,  6.91118094e-03, -1.47158266e+00,
#         3.05784197e-01, -1.06750361e-02, -9.96138270e-01,  6.27746234e-03,
#        -5.57414427e-01])

# %%
model.intercept_
# Out:
# np.float64(45.19251538838434)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# np.float64(21.897765396049483)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(4.679504823808763)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7789410172622859

# %%
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .2 ,random_state=1)
print(y_train.shape, y_test.shape)
# Out:
# (404,) (102,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler().fit(x_train)
x_train = scale.transform(x_train)
x_test = scale.transform(x_test)
x_train
# Out:
# array([[-0.3892494 , -0.49559343, -0.60928978, ..., -0.24857777,
#          0.28674182, -0.96685016],
#        [-0.38783184,  0.57923879, -0.86952633, ...,  0.58214721,
#          0.36669519, -0.82116789],
#        [ 1.43554993, -0.49559343,  1.02669166, ...,  0.81290414,
#          0.43472666,  2.50177533],
#        ...,
#        [ 0.23804008, -0.49559343,  1.02669166, ...,  0.81290414,
#          0.43472666,  0.9145323 ],
#        [-0.36856615, -0.49559343, -0.713092  , ..., -0.47933471,
#          0.21433534, -0.26341291],
#        [-0.39596611, -0.49559343, -0.74818007, ...,  0.35139027,
#          0.43472666, -0.55616491]])

# %%
from sklearn import linear_model

# %%
model = linear_model.SGDRegressor(verbose=1)
model
# Out:
# SGDRegressor(verbose=1)

# %%
model.fit(x_train, np.array(y_train).ravel())
# Out:
# -- Epoch 1
# Norm: 4.30, NNZs: 13, Bias: 15.821640, T: 404, Avg. loss: 100.510510
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 4.81, NNZs: 13, Bias: 19.656949, T: 808, Avg. loss: 23.574945
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 5.30, NNZs: 13, Bias: 21.110598, T: 1212, Avg. loss: 14.239385
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 5.45, NNZs: 13, Bias: 21.769275, T: 1616, Avg. loss: 12.450912
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 5.62, NNZs: 13, Bias: 22.099809, T: 2020, Avg. loss: 11.909518
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 5.71, NNZs: 13, Bias: 22.287213, T: 2424, Avg. loss: 11.651070
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 5.80, NNZs: 13, Bias: 22.392859, T: 2828, Avg. loss: 11.595217
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 5.92, NNZs: 13, Bias: 22.456476, T: 3232, Avg. loss: 11.516253
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 5.96, NNZs: 13, Bias: 22.458595, T: 3636, Avg. loss: 11.458866
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 6.05, NNZs: 13, Bias: 22.523626, T: 4040, Avg. loss: 11.377409
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 6.17, NNZs: 13, Bias: 22.514796, T: 4444, Avg. loss: 11.378751
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 6.23, NNZs: 13, Bias: 22.534720, T: 4848, Avg. loss: 11.339624
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 6.25, NNZs: 13, Bias: 22.525621, T: 5252, Avg. loss: 11.348973
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 6.31, NNZs: 13, Bias: 22.529711, T: 5656, Avg. loss: 11.298517
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 6.30, NNZs: 13, Bias: 22.535949, T: 6060, Avg. loss: 11.277796
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 6.38, NNZs: 13, Bias: 22.505417, T: 6464, Avg. loss: 11.275966
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 6.38, NNZs: 13, Bias: 22.507349, T: 6868, Avg. loss: 11.248585
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 6.44, NNZs: 13, Bias: 22.515088, T: 7272, Avg. loss: 11.250836
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 6.48, NNZs: 13, Bias: 22.528838, T: 7676, Avg. loss: 11.249487
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 6.42, NNZs: 13, Bias: 22.548248, T: 8080, Avg. loss: 11.068857
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 6.55, NNZs: 13, Bias: 22.543251, T: 8484, Avg. loss: 11.156873
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 6.55, NNZs: 13, Bias: 22.537644, T: 8888, Avg. loss: 11.203561
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 6.61, NNZs: 13, Bias: 22.539626, T: 9292, Avg. loss: 11.194676
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 6.58, NNZs: 13, Bias: 22.551742, T: 9696, Avg. loss: 11.168135
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 6.57, NNZs: 13, Bias: 22.554419, T: 10100, Avg. loss: 11.166784
# Total training time: 0.00 seconds.
# Convergence after 25 epochs took 0.00 seconds
# SGDRegressor(verbose=1)

# %%
score = model.score(x_test,y_test)
print('R-squared:',score)
# Out:
# R-squared: 0.7574204390006857

# %%
y_pred = model.predict(x_test)
print('r2:',r2_score(y_test,y_pred),'\nrmse:',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2: 0.7574204390006857
# rmse: 4.896274578827369

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# %%
y = df.price
x = df.drop('price', axis = 1, inplace=False)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .2, random_state=32)

# %%
model = LinearRegression()

# %%
# selector = SequentialFeatureSelector(model, n_features_to_select = 'auto',
#                                      direction = 'forward', scoring = 'neg_mean_squared_error', cv = 5)
# selector.fit(x_train,y_train)
from sklearn.feature_selection import RFE
selector = RFE(estimator = model, n_features_to_select = 5)
selector = selector.fit(x_train,y_train)

# %%
# selected_features = x.columns[selector.get_support()]
# print("Selected features : ", selected_features)
selected_features = x.columns[selector.get_support()]
print("Selected features : ", selected_features)
# Out:
# Selected features :  Index(['chas', 'nox', 'rm', 'dis', 'ptratio'], dtype='object')

# %%
x_train_selected = x_train[selected_features]
x_test_selected = x_test[selected_features]

# %%
# forward selected
model.fit(x_train_selected,y_train)
y_pred = model.predict(x_test_selected)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('mse : ',mse,'\nrmse : ',rmse,'\nr2 : ',r2)
# Out:
# mse :  32.7109356985975
# rmse :  5.719347488883456
# r2 :  0.6382418669817022

# %%
# RFE
model.fit(x_train_selected,y_train)
y_pred = model.predict(x_test_selected)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('mse : ',mse,'\nrmse : ',rmse,'\nr2 : ',r2)
# Out:
# mse :  40.68833799230804
# rmse :  6.378741097764357
# r2 :  0.5500178495858212

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# %%
# ridge = Ridge(alpha=1.0)
# ridge.fit(x_train,y_train)

# coef = pd.Series(ridge.coef_, index = x.columns)

# imp_features = coef[abs(coef)>0.1].index
# y_pred = ridge.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('Select col = ', selected_features)
print('mse : ',mse,'\nrmse : ',rmse,'\nr2 : ',r2)
# Out:
# Select col =  Index(['crim', 'zn', 'indus', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio',
#        'black', 'lstat'],
#       dtype='object')
# mse :  28.930078346899943
# rmse :  5.378668826661476
# r2 :  0.680055280983713

# %%
lasso = Lasso(alpha = 0.1)
lasso.fit(x_train,y_train)
model = SelectFromModel(lasso, prefit = True)
x_train_selected = model.transform(x_train)
x_test_selected = model.transform(x_test)
selected_features = x.columns[model.get_support()]
y_pred = lasso.predict(x_test_selected)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('Select col = ', selected_features)
print('mse : ',mse,'\nrmse : ',rmse,'\nr2 : ',r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 7
#       5 x_test_selected = model.transform(x_test)
#       6 selected_features = x.columns[model.get_support()]
# ----> 7 y_pred = lasso.predict(x_test_selected)
#       8 mse = mean_squared_error(y_test, y_pred)
#       9 rmse = np.sqrt(mse)
#
# File c:\Users\acorn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File c:\Users\acorn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1147, in ElasticNet._decision_function(self, X)
#    1145     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#    1146 else:
# -> 1147     return super()._decision_function(X)
#
# File c:\Users\acorn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File c:\Users\acorn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File c:\Users\acorn\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 11 features, but Lasso is expecting 13 features as input.

# %%
from sklearn.linear_model import ElasticNetCV

# %%
# elasticnetcv
model = ElasticNetCV(cv = 5, random_state=42)
model.fit(x_train,y_train)

selected_features = x.columns[model.coef_ != 0]
x_train_selected = x_train[selected_features]
x_test_selected = x_test[selected_features]

model.fit(x_train_selected,y_train)
y_pred = model.predict(x_test_selected)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('Select col = ', selected_features)
print('mse : ',mse,'\nrmse : ',rmse,'\nr2 : ',r2)
# Out:
# Select col =  Index(['crim', 'zn', 'indus', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio',
#        'black', 'lstat'],
#       dtype='object')
# mse :  38.092972214927364
# rmse :  6.171950438469785
# r2 :  0.5787206261366329

# %%
import xgboost
from xgboost import XGBClassifier
# from sklearn.metrics import accuracy_score

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 로드 및 전처리
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
data = pd.read_csv(url)
features = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
X = data[features]
y = data['Survived']
X['Age'].fillna(X['Age'].mean(), inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 학습 및 변수 중요도 평가
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
model.fit(X_train, y_train)
importances = model.feature_importances_
feature_names = X_train.columns
feature_importances = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importances = feature_importances.sort_values(by='Importance', ascending=False)

# %%
top_features = feature_importances['Feature'].head(2).tolist()
X_train_selected = X_train[top_features]
X_test_selected = X_test[top_features]
model.fit(X_train_selected, y_train)
y_pred = model.predict(X_test_selected)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy with selected features: {accuracy:.2f}")
# Out:
# Accuracy with selected features: 0.69

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importances)
plt.title('Feature Importances from XGBoost')
plt.show()

# %%
col = ['Survived','Pclass','SibSp','Parch','Fare','Age']

# %%
y = df.Survived
x = df.drop(['Survived'], axis = 1, inplace=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.impute import KNNImputer

# %%
knn_imputer = KNNImputer(n_neighbors=2)
data_knn = pd.DataFrame(knn_imputer.fit_transform(data[['Age']]), columns=['Age'])

# %%
df['Age'] = data_knn

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print('mse : ',mse,'\nrmse : ',rmse,'\nr2 : ',r2)
# Out:
# mse :  0.1948035360195722
# rmse :  0.44136553560464165
# r2 :  0.1971326578831839
